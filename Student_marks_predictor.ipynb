# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\suraj\Downloads\student_info.csv")

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.shape
# Out:
# (200, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.scatter(x=df.study_hours,y=df.student_marks)
plt.xlabel("Student Study Hours")
plt.ylabel("Student marks")
plt.title("Scatter Plot Student Study Houre vs Student marks")
plt.show()

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2=df.fillna(df.mean())

# %%
df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
df2.head()
# Out:
#    study_hours  student_marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.995949          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    200 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
x=df.drop("student_marks",axis=1)
y=df["student_marks"]

# %%
x=df2.drop("student_marks",axis="columns")
y=df2.drop("study_hours",axis="columns")
print("shape of x=",x.shape)
print("shape of y=",y.shape)
# Out:
# shape of x= (200, 1)
# shape of y= (200, 1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print("shape of x_train=",x_train.shape)
print("shape of y_train=",y_train.shape)
print("shape of x_test=",x_test.shape)
print("shape of y_test=",x_test.shape)
# Out:
# shape of x_train= (160, 1)
# shape of y_train= (160, 1)
# shape of x_test= (40, 1)
# shape of y_test= (40, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[3.7670993]])

# %%
lr.intercept_
# Out:
# array([51.56958674])

# %%
m=3.93
c=50.44
y=m*10+c
y
# Out:
# 89.74000000000001

# %%
m=3.93
c=50.44
y=m*11+c
y
# Out:
# 93.67

# %%
lr.predict([[11]]).round(2)
# Out:
# C:\Users\suraj\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[93.01]])

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([[83.25089184],
#        [71.1208321 ],
#        [73.11739473],
#        [85.02142851],
#        [73.38109168],
#        [84.19266666],
#        [80.01118644],
#        [81.66871013],
#        [80.7646063 ],
#        [82.00774907],
#        [78.91872765],
#        [84.5317056 ],
#        [77.82626885],
#        [77.67558488],
#        [82.98719489],
#        [85.43580943],
#        [84.64471858],
#        [72.81602678],
#        [78.65503069],
#        [79.10708261],
#        [84.0043117 ],
#        [85.28512546],
#        [74.8502604 ],
#        [81.17898722],
#        [72.25096189],
#        [80.27488339],
#        [78.91872765],
#        [81.89473609],
#        [77.92402025],
#        [82.04542006],
#        [75.52833828],
#        [84.30567964],
#        [71.87425196],
#        [75.56600927],
#        [70.5934382 ],
#        [78.91872765],
#        [75.4153253 ],
#        [84.23033766],
#        [74.20985352],
#        [71.68589699]])

# %%
pd.DataFrame(np.c_[x_test,y_test,y_pred],columns=["study_hours","student_marks_original","Student_marks_predict"])
# Out:
#     study_hours  student_marks_original  Student_marks_predict
# 0      8.410000                   82.50              83.250892
# 1      5.190000                   71.18              71.120832
# 2      5.720000                   73.25              73.117395
# 3      8.880000                   83.64              85.021429
# 4      5.790000                   73.64              73.381092
# 5      8.660000                   86.99              84.192667
# 6      7.550000                   81.18              80.011186
# 7      7.990000                   82.75              81.668710
# 8      7.750000                   79.50              80.764606
# 9      8.080000                   81.70              82.007749
# 10     7.260000                   79.41              78.918728
# 11     8.750000                   85.95              84.531706
# 12     6.970000                   77.19              77.826269
# 13     6.930000                   78.45              77.675585
# 14     8.340000                   84.00              82.987195
# 15     8.990000                   85.46              85.435809
# 16     8.780000                   84.35              84.644719
# 17     5.640000                   73.19              72.816027
# 18     7.190000                   78.21              78.655031
# 19     7.310000                   77.59              79.107083
# 20     8.610000                   83.87              84.004312
# 21     8.950000                   85.15              85.285125
# 22     6.180000                   72.96              74.850260
# 23     7.860000                   80.72              81.178987
# 24     5.490000                   73.61              72.250962
# 25     7.620000                   79.53              80.274883
# 26     7.260000                   78.17              78.918728
# 27     8.050000                   79.63              81.894736
# 28     6.995949                   76.83              77.924020
# 29     8.090000                   82.38              82.045420
# 30     6.360000                   76.04              75.528338
# 31     8.690000                   85.48              84.305680
# 32     5.390000                   71.87              71.874252
# 33     6.370000                   75.04              75.566009
# 34     5.050000                   70.67              70.593438
# 35     7.260000                   79.87              78.918728
# 36     6.330000                   74.49              75.415325
# 37     8.670000                   84.19              84.230338
# 38     6.010000                   75.36              74.209854
# 39     5.340000                   72.10              71.685897

# %%
lr.score(x_test,y_test)
# Out:
# 0.95418753600525

# %%
lr.score(x_train,y_train)
# Out:
# 0.9567927817675176

# %%
plt.scatter(x_train,y_train)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_train,lr.predict(x_train),color="r")

# %%
lr
# Out:
# LinearRegression()

# %%
import joblib
joblib.dump(lr,"Desktop.pkl")
# Out:
# ['Desktop.pkl']

# %%
pwd
# Out:
# 'C:\\Users\\suraj'
